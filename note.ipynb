# %%
import streamlit as st
import json
from tvDatafeed import TvDatafeed, Interval
from highcharts_stock.chart import Chart

# Use full browser width
st.set_page_config(layout="wide")

# --- Define Variables ---
# Change these to your desired symbol, exchange, interval, and number of bars
symbol = 'AAPL'         # Example: Apple Inc.
exchange = 'NASDAQ'
selected_interval = Interval.in_daily  # Daily interval; adjust as needed
n_bars = 100            # Number of bars to retrieve

# --- Retrieve Data ---
tv = TvDatafeed()
data = tv.get_hist(
    symbol=symbol,
    exchange=exchange,
    interval=selected_interval,
    n_bars=n_bars
)

# Build output list: each entry is [timestamp_millis, close]
output_list = []
for idx, row in data.iterrows():
    ts_millis = int(idx.timestamp() * 1000)
    open_val = row["open"]
    high_val = row["high"]
    low_val = row["low"]
    close_val = row["close"]
    volume_val = row["volume"]

    output_list.append([ts_millis, open_val, high_val, low_val ,close_val, volume_val])

# Convert the list to a JSON string
json_string = json.dumps(output_list)
# Out:
# 2025-03-05 13:27:06.650 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
output_list
# Out:
# [[1728419400000, 224.3, 225.98, 223.25, 225.77, 31855693.0],
#  [1728505800000, 225.23, 229.75, 224.83, 229.54, 33591091.0],
#  [1728592200000, 227.78, 229.5, 227.17, 229.04, 28183544.0],
#  [1728678600000, 229.3, 229.41, 227.34, 227.55, 31759188.0],
#  [1728937800000, 228.7, 231.73, 228.6, 231.3, 39882085.0],
#  [1729024200000, 233.61, 237.49, 232.37, 233.85, 64751367.0],
#  [1729110600000, 231.6, 232.12, 229.84, 231.78, 34082240.0],
#  [1729197000000, 233.43, 233.85, 230.52, 232.15, 32993810.0],
#  [1729283400000, 236.18, 236.18, 234.01, 235.0, 46431472.0],
#  [1729542600000, 234.45, 236.85, 234.45, 236.48, 36254470.0],
#  [1729629000000, 233.885, 236.22, 232.6, 235.86, 38846578.0],
#  [1729715400000, 234.08, 235.144, 227.76, 230.76, 52286979.0],
#  [1729801800000, 229.98, 230.82, 228.41, 230.57, 31109503.0],
#  [1729888200000, 229.74, 233.22, 229.57, 231.41, 38802304.0],
#  [1730147400000, 233.32, 234.73, 232.55, 233.4, 36087134.0],
#  [1730233800000, 233.1, 234.325, 232.32, 233.67, 35417247.0],
#  [1730320200000, 232.61, 233.47, 229.55, 230.1, 47070907.0],
#  [1730406600000, 229.34, 229.83, 225.37, 225.91, 64370086.0],
#  [1730493000000, 220.965, 225.35, 220.27, 222.91, 65276741.0],
#  [1730755800000, 220.99, 222.79, 219.71, 222.01, 44944468.0],
#  [1730842200000, 221.795, 223.95, 221.14, 223.45, 28111338.0],
#  [1730928600000, 222.61, 226.065, 221.19, 222.72, 54561121.0],
#  [1731015000000, 224.625, 227.875, 224.57, 227.48, 42137691.0],
#  [1731101400000, 227.17, 228.66, 226.405, 226.96, 38328824.0],
#  [1731360600000, 225.0, 225.7, 221.5, 224.23, 42005602.0],
#  [1731447000000, 224.55, 225.59, 223.355, 224.23, 40398299.0],
#  [1731533400000, 224.01, 226.65, 222.76, 225.12, 48566217.0],
#  [1731619800000, 225.02, 228.87, 225.0, 228.22, 44923941.0],
#  [1731706200000, 226.4, 226.92, 224.27, 225.0, 47923696.0],
#  [1731965400000, 225.25, 229.74, 225.17, 228.02, 44686020.0],
#  [1732051800000, 226.98, 230.16, 226.66, 228.28, 36211774.0],
#  [1732138200000, 228.06, 229.93, 225.89, 229.0, 35169566.0],
#  [1732224600000, 228.88, 230.155, 225.7103, 228.52, 42108327.0],
#  [1732311000000, 228.06, 230.7199, 228.06, 229.87, 38168252.0],
#  [1732570200000, 231.46, 233.245, 229.74, 232.87, 90152832.0],
#  [1732656600000, 233.33, 235.57, 233.33, 235.06, 45986189.0],
#  [1732743000000, 234.465, 235.69, 233.8101, 234.93, 33498439.0],
#  [1732915800000, 234.805, 237.81, 233.97, 237.33, 28481377.0],
#  [1733175000000, 237.27, 240.79, 237.16, 239.59, 48137103.0],
#  [1733261400000, 239.81, 242.76, 238.9, 242.65, 38861017.0],
#  [1733347800000, 242.87, 244.11, 241.25, 243.01, 44383935.0],
#  [1733434200000, 243.99, 244.54, 242.13, 243.04, 40033878.0],
#  [1733520600000, 242.905, 244.63, 242.08, 242.84, 36870619.0],
#  [1733779800000, 241.83, 247.24, 241.75, 246.75, 44649232.0],
#  [1733866200000, 246.89, 248.21, 245.34, 247.77, 36914806.0],
#  [1733952600000, 247.96, 250.8, 246.2601, 246.49, 45205814.0],
#  [1734039000000, 246.89, 248.74, 245.68, 247.96, 32777532.0],
#  [1734125400000, 247.815, 249.2902, 246.24, 248.13, 33155290.0],
#  [1734384600000, 247.99, 251.38, 247.65, 251.04, 51694753.0],
#  [1734471000000, 250.08, 253.83, 249.78, 253.48, 51356360.0],
#  [1734557400000, 252.16, 254.28, 247.74, 248.05, 56774101.0],
#  [1734643800000, 247.5, 252.0, 247.0949, 249.79, 60882264.0],
#  [1734730200000, 248.04, 255.0, 245.69, 254.49, 147495267.0],
#  [1734989400000, 254.77, 255.65, 253.45, 255.27, 40858774.0],
#  [1735075800000, 255.49, 258.21, 255.29, 258.2, 23234705.0],
#  [1735248600000, 258.19, 260.1, 257.63, 259.02, 27262983.0],
#  [1735335000000, 257.83, 258.7, 253.06, 255.59, 42355321.0],
#  [1735594200000, 252.23, 253.5, 250.75, 252.2, 35557542.0],
#  [1735680600000, 252.44, 253.28, 249.43, 250.42, 39480718.0],
#  [1735853400000, 248.93, 249.1, 241.8201, 243.85, 55740731.0],
#  [1735939800000, 243.36, 244.18, 241.89, 243.36, 40244114.0],
#  [1736199000000, 244.31, 247.33, 243.2, 245.0, 45045571.0],
#  [1736285400000, 242.98, 245.55, 241.35, 242.21, 40855960.0],
#  [1736371800000, 241.92, 243.7123, 240.05, 242.7, 37628940.0],
#  [1736544600000, 240.01, 240.16, 233.0, 236.85, 61710856.0],
#  [1736803800000, 233.53, 234.67, 229.72, 234.4, 49630725.0],
#  [1736890200000, 234.75, 236.12, 232.472, 233.28, 39435294.0],
#  [1736976600000, 234.635, 238.96, 234.43, 237.87, 39831969.0],
#  [1737063000000, 237.35, 238.01, 228.03, 228.26, 71759052.0],
#  [1737149400000, 232.115, 232.29, 228.48, 229.98, 68488301.0],
#  [1737495000000, 224.0, 224.42, 219.38, 222.64, 98070429.0],
#  [1737581400000, 219.79, 224.12, 219.79, 223.83, 64126500.0],
#  [1737667800000, 224.74, 227.03, 222.3, 223.66, 60234760.0],
#  [1737754200000, 224.78, 225.63, 221.41, 222.78, 54697907.0],
#  [1738013400000, 224.02, 232.15, 223.98, 229.86, 94863418.0],
#  [1738099800000, 230.85, 240.19, 230.81, 238.26, 75707569.0],
#  [1738186200000, 234.12, 239.855, 234.01, 239.36, 45486100.0],
#  [1738272600000, 238.665, 240.79, 237.21, 237.59, 55658279.0],
#  [1738359000000, 247.19, 247.19, 233.44, 236.0, 101075128.0],
#  [1738618200000, 229.99, 231.83, 225.7, 228.01, 73063301.0],
#  [1738704600000, 227.25, 233.13, 226.65, 232.8, 45067301.0],
#  [1738791000000, 228.53, 232.67, 228.27, 232.47, 39664989.0],
#  [1738877400000, 231.285, 233.8, 230.425, 233.22, 29925349.0],
#  [1738963800000, 232.6, 234.0, 227.26, 227.63, 39707224.0],
#  [1739223000000, 229.57, 230.585, 227.2, 227.65, 33115645.0],
#  [1739309400000, 228.2, 235.23, 228.13, 232.62, 53718362.0],
#  [1739395800000, 231.2, 236.96, 230.68, 236.87, 45243292.0],
#  [1739482200000, 236.91, 242.3399, 235.57, 241.53, 53614054.0],
#  [1739568600000, 241.25, 245.55, 240.99, 244.6, 40896227.0],
#  [1739914200000, 244.15, 245.18, 241.84, 244.47, 48822491.0],
#  [1740000600000, 244.66, 246.01, 243.1604, 244.87, 32204215.0],
#  [1740087000000, 244.94, 246.78, 244.29, 245.83, 32316907.0],
#  [1740173400000, 245.95, 248.69, 245.22, 245.55, 53197431.0],
#  [1740432600000, 244.925, 248.86, 244.42, 247.1, 51326396.0],
#  [1740519000000, 248.0, 250.0, 244.91, 247.04, 48013272.0],
#  [1740605400000, 244.33, 244.98, 239.13, 240.36, 44433564.0],
#  [1740691800000, 239.41, 242.46, 237.06, 237.3, 41153639.0],
#  [1740778200000, 236.95, 242.09, 230.2, 241.84, 56833360.0],
#  [1741037400000, 241.79, 244.0272, 236.112, 238.03, 47183985.0],
#  [1741123800000, 237.705, 240.07, 234.68, 235.93, 53798062.0]]

# %%
import pandas as pd

def create_bear_plotbands(bear_list):
    plotbands = []
    for bear in bear_list:
        plotband = {
            'color': '#f8cdcd',
            'from': bear['bear_top'],
            'to': bear['bear_btm'],
            'zIndex': 2,
            'label': {
                'text': 'Support Zone'  # Change to desired label text
            }
        }
        plotbands.append(plotband)
    return {'plotBands': plotbands}

# Example usage with sample data:
if __name__ == "__main__":
    sample_data = [
        {'index': 385,
         'bear_top': 109588.0,
         'bear_btm': 104569.0,
         'bear_avg': 107078.5,
         'bear_left': pd.Timestamp('2025-01-20 00:00:00'),
         'value': 109588.0},
        {'index': 399,
         'bear_top': 102500.01,
         'bear_btm': 96865.505,
         'bear_avg': 99682.7575,
         'bear_left': pd.Timestamp('2025-02-03 00:00:00'),
         'value': 102500.01},
        {'index': 417,
         'bear_top': 99475.0,
         'bear_btm': 97173.475,
         'bear_avg': 98324.2375,
         'bear_left': pd.Timestamp('2025-02-21 00:00:00'),
         'value': 99475.0}
    ]
    
    formatted_plotbands = create_bear_plotbands(sample_data)
    print(formatted_plotbands)
# Out:
# {'plotBands': [{'color': '#f8cdcd', 'from': 109588.0, 'to': 104569.0, 'zIndex': 2, 'label': {'text': 'Support Zone'}}, {'color': '#f8cdcd', 'from': 102500.01, 'to': 96865.505, 'zIndex': 2, 'label': {'text': 'Support Zone'}}, {'color': '#f8cdcd', 'from': 99475.0, 'to': 97173.475, 'zIndex': 2, 'label': {'text': 'Support Zone'}}]}

# %%
from orderblockdetector import *

# %%
find_most_stacked_point(formatted_plotbands)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 find_most_stacked_point(formatted_plotbands)
#
# File c:\Users\chaya\OneDrive\Desktop\project\sinewave\orderblockdetector.py:184, in find_most_stacked_point(plotBands)
#     181 # Build events: +1 for the start and -1 for the end of each interval.
#     182 for box in plotBands:
#     183     # Determine the lower and upper boundaries regardless of key order.
# --> 184     lower = min(box['from'], box['to'])
#     185     upper = max(box['from'], box['to'])
#     186     events.append((lower, 1))
#
# TypeError: string indices must be integers, not 'str'

# %%
formatted_plotbands
# Out:
# {'plotBands': [{'color': '#f8cdcd',
#    'from': 109588.0,
#    'to': 104569.0,
#    'zIndex': 2,
#    'label': {'text': 'Support Zone'}},
#   {'color': '#f8cdcd',
#    'from': 102500.01,
#    'to': 96865.505,
#    'zIndex': 2,
#    'label': {'text': 'Support Zone'}},
#   {'color': '#f8cdcd',
#    'from': 99475.0,
#    'to': 97173.475,
#    'zIndex': 2,
#    'label': {'text': 'Support Zone'}}]}
